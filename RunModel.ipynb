# %%
from google.colab import drive
 
drive.mount('/content/drive')
 
# %cd /content/drive/My Drive/CS152 Project Materials/
 
# %tensorflow_version 1.x
import tensorflow as tf
# !pip install googledrivedownloader
 
# !nvcc test_nvcc.cu -o test_nvcc -run
 
print('Tensorflow version: {}'.format(tf.__version__) )
# !nvidia-smi -L
print('GPU Identified at: {}'.format(tf.test.gpu_device_name()))
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/CS152 Project Materials
# TensorFlow 1.x selected.
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.6/dist-packages (0.4)
# gcc: error: test_nvcc.cu: No such file or directory
# gcc: warning: ‘-x c++’ after last input file has no effect
# gcc: fatal error: no input files
# compilation terminated.
# Tensorflow version: 1.15.2
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-7930e111-fcb4-8105-ed70-21a57ba7d65c)
# GPU Identified at: /device:GPU:0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Nov 12 07:04:35 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %cd stylegan2
# Out:
# /content/drive/My Drive/CS152 Project Materials/stylegan2

# %%
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=kamalaDataset --mirror-augment=true
# Out:
# Local submit - run_dir: results/00018-stylegan2-kamalaDataset-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x6f02000 @  0x7fb522e15001 0x7fb51f8a1765 0x7fb51f905bb0 0x7fb51f907a4f 0x7fb51f99e048 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588e5c 0x59fd0e
# tcmalloc: large alloc 4294967296 bytes == 0x7fb3512c8000 @  0x7fb522e131e7 0x7fb51f8a15e1 0x7fb51f905c78 0x7fb51f905f37 0x7fb51f99df28 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7fb2502c6000 @  0x7fb522e131e7 0x7fb51f8a15e1 0x7fb51f905c78 0x7fb51f905f37 0x7fb4dccf50c5 0x7fb4dc678902 0x7fb4dc678eb2 0x7fb4dc631c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# Dataset shape = [3, 512, 512]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "/content/drive/MyDrive/CS152 Project Materials/stylegan2/2020-01-11-skylion-stylegan2-animeportraits-networksnapshot-024664.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
#
# G                             Params    OutputShape         WeightShape
# ---                           ---       ---                 ---
# latents_in                    -         (?, 512)            -
# labels_in                     -         (?, 0)              -
# lod                           -         ()                  -
# dlatent_avg                   -         (512,)              -
# G_mapping/latents_in          -         (?, 512)            -
# G_mapping/labels_in           -         (?, 0)              -
# G_mapping/Normalize           -         (?, 512)            -
# G_mapping/Dense0              262656    (?, 512)            (512, 512)
# G_mapping/Dense1              262656    (?, 512)            (512, 512)
# G_mapping/Dense2              262656    (?, 512)            (512, 512)
# G_mapping/Dense3              262656    (?, 512)            (512, 512)
# G_mapping/Dense4              262656    (?, 512)            (512, 512)
# G_mapping/Dense5              262656    (?, 512)            (512, 512)
# G_mapping/Dense6              262656    (?, 512)            (512, 512)
# G_mapping/Dense7              262656    (?, 512)            (512, 512)
# G_mapping/Broadcast           -         (?, 16, 512)        -
# G_mapping/dlatents_out        -         (?, 16, 512)        -
# Truncation/Lerp               -         (?, 16, 512)        -
# G_synthesis/dlatents_in       -         (?, 16, 512)        -
# G_synthesis/4x4/Const         8192      (?, 512, 4, 4)      (1, 512, 4, 4)
# G_synthesis/4x4/Conv          2622465   (?, 512, 4, 4)      (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB         264195    (?, 3, 4, 4)        (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up      2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Conv1         2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Upsample      -         (?, 3, 8, 8)        -
# G_synthesis/8x8/ToRGB         264195    (?, 3, 8, 8)        (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up    2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Conv1       2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Upsample    -         (?, 3, 16, 16)      -
# G_synthesis/16x16/ToRGB       264195    (?, 3, 16, 16)      (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up    2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Conv1       2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Upsample    -         (?, 3, 32, 32)      -
# G_synthesis/32x32/ToRGB       264195    (?, 3, 32, 32)      (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up    2622465   (?, 512, 64, 64)    (3, 3, 512, 512)
# G_synthesis/64x64/Conv1       2622465   (?, 512, 64, 64)    (3, 3, 512, 512)
# G_synthesis/64x64/Upsample    -         (?, 3, 64, 64)      -
# G_synthesis/64x64/ToRGB       264195    (?, 3, 64, 64)      (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up  1442561   (?, 256, 128, 128)  (3, 3, 512, 256)
# G_synthesis/128x128/Conv1     721409    (?, 256, 128, 128)  (3, 3, 256, 256)
# G_synthesis/128x128/Upsample  -         (?, 3, 128, 128)    -
# G_synthesis/128x128/ToRGB     132099    (?, 3, 128, 128)    (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up  426369    (?, 128, 256, 256)  (3, 3, 256, 128)
# G_synthesis/256x256/Conv1     213249    (?, 128, 256, 256)  (3, 3, 128, 128)
# G_synthesis/256x256/Upsample  -         (?, 3, 256, 256)    -
# G_synthesis/256x256/ToRGB     66051     (?, 3, 256, 256)    (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up  139457    (?, 64, 512, 512)   (3, 3, 128, 64)
# G_synthesis/512x512/Conv1     69761     (?, 64, 512, 512)   (3, 3, 64, 64)
# G_synthesis/512x512/Upsample  -         (?, 3, 512, 512)    -
# G_synthesis/512x512/ToRGB     33027     (?, 3, 512, 512)    (1, 1, 64, 3)
# G_synthesis/images_out        -         (?, 3, 512, 512)    -
# G_synthesis/noise0            -         (1, 1, 4, 4)        -
# G_synthesis/noise1            -         (1, 1, 8, 8)        -
# G_synthesis/noise2            -         (1, 1, 8, 8)        -
# G_synthesis/noise3            -         (1, 1, 16, 16)      -
# G_synthesis/noise4            -         (1, 1, 16, 16)      -
# G_synthesis/noise5            -         (1, 1, 32, 32)      -
# G_synthesis/noise6            -         (1, 1, 32, 32)      -
# G_synthesis/noise7            -         (1, 1, 64, 64)      -
# G_synthesis/noise8            -         (1, 1, 64, 64)      -
# G_synthesis/noise9            -         (1, 1, 128, 128)    -
# G_synthesis/noise10           -         (1, 1, 128, 128)    -
# G_synthesis/noise11           -         (1, 1, 256, 256)    -
# G_synthesis/noise12           -         (1, 1, 256, 256)    -
# G_synthesis/noise13           -         (1, 1, 512, 512)    -
# G_synthesis/noise14           -         (1, 1, 512, 512)    -
# images_out                    -         (?, 3, 512, 512)    -
# ---                           ---       ---                 ---
# Total                         30276583
#
#
# D                    Params    OutputShape         WeightShape
# ---                  ---       ---                 ---
# images_in            -         (?, 3, 512, 512)    -
# labels_in            -         (?, 0)              -
# 512x512/FromRGB      256       (?, 64, 512, 512)   (1, 1, 3, 64)
# 512x512/Conv0        36928     (?, 64, 512, 512)   (3, 3, 64, 64)
# 512x512/Conv1_down   73856     (?, 128, 256, 256)  (3, 3, 64, 128)
# 512x512/Skip         8192      (?, 128, 256, 256)  (1, 1, 64, 128)
# 256x256/Conv0        147584    (?, 128, 256, 256)  (3, 3, 128, 128)
# 256x256/Conv1_down   295168    (?, 256, 128, 128)  (3, 3, 128, 256)
# 256x256/Skip         32768     (?, 256, 128, 128)  (1, 1, 128, 256)
# 128x128/Conv0        590080    (?, 256, 128, 128)  (3, 3, 256, 256)
# 128x128/Conv1_down   1180160   (?, 512, 64, 64)    (3, 3, 256, 512)
# 128x128/Skip         131072    (?, 512, 64, 64)    (1, 1, 256, 512)
# 64x64/Conv0          2359808   (?, 512, 64, 64)    (3, 3, 512, 512)
# 64x64/Conv1_down     2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 64x64/Skip           262144    (?, 512, 32, 32)    (1, 1, 512, 512)
# 32x32/Conv0          2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 32x32/Conv1_down     2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 32x32/Skip           262144    (?, 512, 16, 16)    (1, 1, 512, 512)
# 16x16/Conv0          2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 16x16/Conv1_down     2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 16x16/Skip           262144    (?, 512, 8, 8)      (1, 1, 512, 512)
# 8x8/Conv0            2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
0x5095c8 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x508ec2 0x594a01
# tcmalloc: large alloc 4294967296 bytes == 0x7fac05280000 @  0x7fb522e131e7 0x7fb51f8a15e1 0x7fb51f905c78 0x7fb51f905f37 0x7fb51f99df28 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7fac05280000 @  0x7fb522e131e7 0x7fb51f8a15e1 0x7fb51f905c78 0x7fb51f905f37 0x7fb4dccf50c5 0x7fb4dc678902 0x7fb4dc678eb2 0x7fb4dc631c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# network-snapshot-007012        time 24m 46s      fid50k 343.6572
# tick 3     kimg 7018.2   lod 0.00  minibatch 32   time 2h 40m 38s   sec/tick 1684.3  sec/kimg 279.96  maintenance 1505.7 gpumem 8.4
# network-snapshot-007018        time 24m 41s      fid50k 288.4465
# tick 4     kimg 7024.2   lod 0.00  minibatch 32   time 3h 33m 46s   sec/tick 1687.8  sec/kimg 280.54  maintenance 1500.8 gpumem 8.4
# network-snapshot-007024        time 24m 42s      fid50k 292.8169
# tick 5     kimg 7030.2   lod 0.00  minibatch 32   time 4h 26m 53s   sec/tick 1683.8  sec/kimg 279.89  maintenance 1503.4 gpumem 8.4
# network-snapshot-007030        time 24m 40s      fid50k 262.2812
# tick 6     kimg 7036.2   lod 0.00  minibatch 32   time 5h 19m 59s   sec/tick 1685.0  sec/kimg 280.08  maintenance 1500.3 gpumem 8.4
# network-snapshot-007036        time 24m 40s      fid50k 220.2648
# tick 7     kimg 7042.2   lod 0.00  minibatch 32   time 6h 13m 04s   sec/tick 1684.2  sec/kimg 279.95  maintenance 1501.2 gpumem 8.4
# network-snapshot-007042        time 24m 35s      fid50k 199.0630
# tick 8     kimg 7048.3   lod 0.00  minibatch 32   time 7h 06m 03s   sec/tick 1683.6  sec/kimg 279.86  maintenance 1495.5 gpumem 8.4
# network-snapshot-007048        time 24m 41s      fid50k 184.8506
# tick 9     kimg 7054.3   lod 0.00  minibatch 32   time 7h 59m 07s   sec/tick 1682.4  sec/kimg 279.65  maintenance 1501.5 gpumem 8.4
# network-snapshot-007054        time 24m 35s      fid50k 154.5340
# tick 10    kimg 7060.3   lod 0.00  minibatch 32   time 8h 52m 06s   sec/tick 1683.5  sec/kimg 279.83  maintenance 1495.3 gpumem 8.4
# network-snapshot-007060        time 24m 36s      fid50k 128.5245
# tick 11    kimg 7066.3   lod 0.00  minibatch 32   time 9h 45m 07s   sec/tick 1684.0  sec/kimg 279.93  maintenance 1496.9 gpumem 8.4
# network-snapshot-007066        time 24m 42s      fid50k 116.3027
# tick 12    kimg 7072.3   lod 0.00  minibatch 32   time 10h 38m 13s  sec/tick 1683.3  sec/kimg 279.80  maintenance 1502.5 gpumem 8.4
# network-snapshot-007072        time 24m 38s      fid50k 111.0263

# %%
# !ls
# Out:
# sample_data
